# %% [markdown]
# # Red Wine Quality

# %%
import numpy as np 
import pandas as pd                                         
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df = pd.read_csv('datasets/winequality-red.csv')

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.info(memory_usage='Deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.memory_usage(deep=True)
# Out:
# Index                     128
# fixed acidity           12792
# volatile acidity        12792
# citric acid             12792
# residual sugar          12792
# chlorides               12792
# free sulfur dioxide     12792
# total sulfur dioxide    12792
# density                 12792
# pH                      12792
# sulphates               12792
# alcohol                 12792
# quality                 12792
# dtype: int64

# %%
list(df.columns)
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df['quality'] = df['quality'].apply(lambda x: 'Good' if x>6 else 'Bad')

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
for i in df.columns:
    print('-----------------------------------------::for {} column::-----------------------------------------'.format(i))
    l = max(list(df[i]))
    s = min(list(df[i]))
    
    print('min value: ', s)
    print('max value: ', l)
    
    print('{} column ranges between {} and {}'.format(i, s, l))
    print('Total number of unique value is: ', df[i].nunique())
    print('-------------------------------------------------------------------------------------------------------------------------------',end='\n\n')
# Out:
# -----------------------------------------::for fixed acidity column::-----------------------------------------
# min value:  4.6
# max value:  15.9
# fixed acidity column ranges between 4.6 and 15.9
# Total number of unique value is:  96
# -------------------------------------------------------------------------------------------------------------------------------
#
# -----------------------------------------::for volatile acidity column::-----------------------------------------
# min value:  0.12
# max value:  1.58
# volatile acidity column ranges between 0.12 and 1.58
# Total number of unique value is:  143
# -------------------------------------------------------------------------------------------------------------------------------
#
# -----------------------------------------::for citric acid column::-----------------------------------------
# min value:  0.0
# max value:  1.0
# citric acid column ranges between 0.0 and 1.0
# Total number of unique value is:  80
# ...

# %% [markdown]
# ## Data Visualization

# %%
v1 = sns.countplot(data=df, x='quality')
plt.title("Count by Quality")
for bar in v1.patches:
    v1.annotate(bar.get_height(), (bar.get_x()+0.3, bar.get_height()))
plt.show()

# %%
col = list(df.columns)
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(15, 12))
axes = axes.flatten()

for i in range(11):
    sns.histplot(df.iloc[:, i], kde=True, ax=axes[i])
    axes[i].set_title('Column {}'.format(col[i]))

for j in range(11, 12):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
col = list(df.columns)
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(15, 12))
axes = axes.flatten()

for i in range(11):
    sns.kdeplot(data = df, x = col[i], hue='quality', ax=axes[i], fill=True)
    axes[i].set_title('Column {}'.format(col[i]))

for j in range(11, 12):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(30, 50))
plt.subplot(6,2,1)
sns.boxplot(x=df['fixed acidity'])

plt.subplot(6,2,2)
sns.boxplot(x=df['volatile acidity'])

plt.subplot(6,2,3)
sns.boxplot(x=df['citric acid'])

plt.subplot(6,2,4)
sns.boxplot(x=df['residual sugar'])

plt.subplot(6,2,5)
sns.boxplot(x=df['chlorides'])

plt.subplot(6,2,6)
sns.boxplot(x=df['free sulfur dioxide'])

plt.subplot(6,2,7)
sns.boxplot(x=df['total sulfur dioxide'])

plt.subplot(6,2,8)
sns.boxplot(x=df['density'])

plt.subplot(6,2,9)
sns.boxplot(x=df['pH'])

plt.subplot(6,2,10)
sns.boxplot(x=df['sulphates'])

plt.subplot(6,2,11)
sns.boxplot(x=df['alcohol'])

plt.show()

# %%
corr_matrix = df.corr(numeric_only=True)
corr_matrix
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# ...

# %%
plt.figure(figsize=(10,5))
ax = sns.heatmap(corr_matrix, annot=True, linewidth=.10, cmap=sns.cubehelix_palette(as_cmap=True))
plt.show()

# %%
df.drop_duplicates(inplace=True, ignore_index = True)

# %%
df['quality'].unique()
# Out:
# array(['Bad', 'Good'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# %%
encoder.fit(df['quality'])
# Out:
# LabelEncoder()

# %%
encoder.classes_
# Out:
# array(['Bad', 'Good'], dtype=object)

# %%
df['quality'] = encoder.transform(df['quality'])

# %%
X = df.drop(['quality'], axis=1)
y = df['quality']

# %%
from sklearn.model_selection import train_test_split

X_train , X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, shuffle=True)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.classes_
# Out:
# array([0, 1])

# %%
def pred(test_data):
    data = np.array(test_data)
    data = data.reshape(1, -1)
    
    prediction = model.predict(data)
    if prediction == 0:
        print("Good")
    elif prediction == 1:
        print("Bad")

# %%
pred(X_test.iloc[1, :])
# Out:
# Good
